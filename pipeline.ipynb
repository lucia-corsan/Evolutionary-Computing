# %% [markdown]
# ### Configuración inicial

# %%
import os
import json
import time
import warnings
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.base import clone
from evopt import EvolutionaryOptimizer

warnings.filterwarnings("ignore")

# =====================================================
# 🔧 CONFIGURACIÓN GLOBAL
# =====================================================
RESULTS_DIR = "results"
os.makedirs(RESULTS_DIR, exist_ok=True)

DATASETS = {
    "California": "data/california.csv",
    "Diabetes": "data/diabetes.csv"
}

MAXTIME = 180           # Tiempo máximo del optimizador por ejecución (segundos)
TEST_SIZE = 0.25        # Porcentaje de validación
RANDOM_STATE = 42

# %% [markdown]
# ### Definición de modelos

# %%
# Modelos representativos y probables en evaluación del profesor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, BayesianRidge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import HuberRegressor


MODELOS = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(alpha=1.0, random_state=RANDOM_STATE),
    "Lasso": Lasso(alpha=0.001, random_state=RANDOM_STATE, max_iter=2000),
    "ElasticNet": ElasticNet(alpha=0.001, random_state=RANDOM_STATE, max_iter=2000),
    "BayesianRidge": BayesianRidge(),
    "DecisionTree": DecisionTreeRegressor(random_state=RANDOM_STATE),
    "RandomForest": RandomForestRegressor(n_estimators=100, random_state=RANDOM_STATE, n_jobs=-1),
    "ExtraTrees": ExtraTreesRegressor(n_estimators=100, random_state=RANDOM_STATE, n_jobs=-1),
    "GradientBoosting": GradientBoostingRegressor(random_state=RANDOM_STATE),
    "AdaBoost": AdaBoostRegressor(n_estimators=100, random_state=RANDOM_STATE),
    "SVR": SVR(),
    "MLP": MLPRegressor(hidden_layer_sizes=(100,), max_iter=500, random_state=RANDOM_STATE),
    "KNeighbors": KNeighborsRegressor(n_neighbors=5),
    "Huber": HuberRegressor(max_iter=2000)


}

print(f"🧠 Se evaluarán {len(MODELOS)} modelos en cada escenario.")
# Out:
# 🧠 Se evaluarán 14 modelos en cada escenario.

# %% [markdown]
# ### Escenarios evolutivos

# %%
# ===============================================================
# 🧬 Escenarios evolutivos originales + variaciones paramétricas
# ===============================================================

CONFIGURACIONES = [
    {"name": "EquilibrioAdaptativo", "pop_size": 25, "mutation_prob": 0.35, "elitism": True,
     "complexity_penalty": 0.001, "patience": 30, "generations": 9999},

    {"name": "DiversidadDirigida", "pop_size": 50, "mutation_prob": 0.55, "elitism": True,
     "complexity_penalty": 0.001, "patience": 40, "generations": 9999},

    {"name": "SinElitismo", "pop_size": 25, "mutation_prob": 0.35, "elitism": False,
     "complexity_penalty": 0.001, "patience": 30, "generations": 9999},

    {"name": "MutacionAlta", "pop_size": 25, "mutation_prob": 0.6, "elitism": True,
     "complexity_penalty": 0.001, "patience": 30, "generations": 9999},

    {"name": "PenalizacionFuerte", "pop_size": 25, "mutation_prob": 0.35, "elitism": True,
     "complexity_penalty": 0.005, "patience": 30, "generations": 9999},

    {"name": "PoblacionPequena", "pop_size": 10, "mutation_prob": 0.35, "elitism": True,
     "complexity_penalty": 0.001, "patience": 30, "generations": 9999},

    {"name": "MicroEvolucion", "pop_size": 12, "mutation_prob": 0.3, "elitism": True,
     "complexity_penalty": 0.001, "patience": 60, "generations": 9999}
]


print(f"🧪 Se evaluarán {len(CONFIGURACIONES)} escenarios evolutivos en total.")
# Out:
# 🧪 Se evaluarán 12 escenarios evolutivos en total.

# %% [markdown]
# ### Funciones auxiliares

# %%
def evaluar_modelo(modelo, X_train, X_val, y_train, y_val):
    """Entrena un modelo y calcula el MSE."""
    m = clone(modelo)
    m.fit(X_train, y_train)
    y_pred = m.predict(X_val)
    return mean_squared_error(y_val, y_pred)


def evaluar_configuracion(cfg_name, evo_params, dataset_name, path_csv):
    """
    Ejecuta una configuración del EvolutionaryOptimizer sobre un dataset,
    mostrando el proceso como una bitácora de experimento.
    """
    evo_params = {k: v for k, v in evo_params.items() if k != "name"}

    # ================================
    # CABECERA DEL EXPERIMENTO
    # ================================
    print("\n" + "=" * 90)
    print(f"🧩 Escenario: {cfg_name} | Dataset: {dataset_name}")
    print("=" * 90)
    print(f"🔧 Parámetros evolutivos → {evo_params}")

    # ================================
    # PREPARACIÓN DE DATOS
    # ================================
    df = pd.read_csv(path_csv)
    X = df.iloc[:, :-1].values
    y = df.iloc[:, -1].values
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE
    )

    # ================================
    # ENTRENAMIENTO DEL OPTIMIZADOR
    # ================================
    print("\n🚀 Iniciando optimización evolutiva...")
    opt = EvolutionaryOptimizer(maxtime=MAXTIME, **evo_params)
    start = time.time()
    opt.fit(X_train, y_train)
    elapsed = time.time() - start

    print(f"✅ Finalizado en {elapsed:.1f} segundos | Fitness óptimo: {opt.best_fit:.4f}")

    X_train_opt = opt.transform(X_train)
    X_val_opt = opt.transform(X_val)
    n_features = X_train_opt.shape[1]

    print(f"✨ Conjunto de entrenamiento ampliado a {n_features} variables tras la evolución.")
    print("-" * 70)

    # ================================
    # EVALUACIÓN POR MODELO
    # ================================
    resultados = []
    inicio_modelos = time.time()

    for i, (nombre, modelo) in enumerate(MODELOS.items(), 1):
        print(f"\n[{i:02d}/{len(MODELOS)}] 🧠 Evaluando {nombre}...")

        try:
            t0 = time.time()
            mse_base = evaluar_modelo(modelo, X_train, X_val, y_train, y_val)
            mse_opt = evaluar_modelo(modelo, X_train_opt, X_val_opt, y_train, y_val)
            duracion = time.time() - t0
            mejora = 100 * (1 - mse_opt / mse_base)
            tendencia = "⬆️ mejora" if mejora > 0 else "⬇️ empeora"

            print(f"   • MSE base: {mse_base:.4f}")
            print(f"   • MSE tras evolución: {mse_opt:.4f}")
            print(f"   • Diferencia: {mejora:+.2f}% ({tendencia}) — {duracion:.2f}s")

            resultados.append({
                "config": cfg_name,
                "dataset": dataset_name,
                "modelo": nombre,
                "mse_original": mse_base,
                "mse_optimizado": mse_opt,
                "mejora_%": mejora,
                "tiempo_modelo_s": duracion,
                "tiempo_optimizador_s": elapsed,
                "num_features": n_features,
                "fitness_final": opt.best_fit,
                "elitism": evo_params.get("elitism"),
                "mutation_prob": evo_params.get("mutation_prob"),
                "complexity_penalty": evo_params.get("complexity_penalty"),
                "pop_size": evo_params.get("pop_size"),
                "patience": evo_params.get("patience")
            })

        except Exception as e:
            print(f"   ⚠️ No se pudo evaluar {nombre}: {e}")
            continue

    # ================================
    # RESUMEN DEL ESCENARIO
    # ================================
    total_modelos = len(resultados)
    tiempo_total = time.time() - inicio_modelos
    mean_improvement = np.mean([r["mejora_%"] for r in resultados]) if resultados else 0

    print("\n" + "-" * 70)
    print(f"🧾 Resumen del escenario {cfg_name}:")
    print(f"   ▫️ Modelos evaluados: {total_modelos}")
    print(f"   ▫️ Mejora media: {mean_improvement:.2f}%")
    print(f"   ▫️ Tiempo total evaluación modelos: {tiempo_total:.1f}s")
    print(f"   ▫️ Tiempo optimizador: {elapsed:.1f}s")
    print(f"   ▫️ Features generadas: {n_features}")
    print("-" * 70)

    return resultados

# %% [markdown]
# ### Ejecución global de experimentos

# %% [markdown]
# #### Probando con todos los escenarios (sin descartes)

# %%
# Ejecutar todas las configuraciones en todos los datasets
all_results = []

for cfg in CONFIGURACIONES:
    cfg_name = cfg["name"]
    evo_params = {k: v for k, v in cfg.items() if k != "name"}  # elimina "name"

    for dataset_name, path in DATASETS.items():
        res = evaluar_configuracion(cfg_name, evo_params, dataset_name, path)
        all_results.extend(res)
# Out:
# ==========================================================================================
# 🧩 Escenario: DiversidadDirigida | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 50, 'mutation_prob': 0.55, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 40, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 96
# [DONE] Best fitness: -0.40687 | Time: 53.7s
# ✅ Finalizado en 53.7 segundos | Fitness óptimo: -0.4069
# ✨ Conjunto de entrenamiento ampliado a 10 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4579
#    • Diferencia: +15.38% (⬆️ mejora) — 0.01s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4579
#    • Diferencia: +15.37% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 0.5394
#    • MSE tras evolución: 0.4568
#    • Diferencia: +15.31% (⬆️ mejora) — 0.76s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 0.5397
#    • MSE tras evolución: 0.4572
#    • Diferencia: +15.29% (⬆️ mejora) — 0.80s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 0.5408
#    • MSE tras evolución: 0.4579
#    • Diferencia: +15.34% (⬆️ mejora) — 0.00s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 0.5285
#    • MSE tras evolución: 0.5214
#    • Diferencia: +1.35% (⬆️ mejora) — 0.41s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 0.2542
#    • MSE tras evolución: 0.2553
#    • Diferencia: -0.43% (⬇️ empeora) — 4.04s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 0.2486
#    • MSE tras evolución: 0.2713
#    • Diferencia: -9.13% (⬇️ empeora) — 1.62s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 0.2895
#    • MSE tras evolución: 0.2865
#    • Diferencia: +1.05% (⬆️ mejora) — 7.47s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 0.8194
#    • MSE tras evolución: 0.7971
#    • Diferencia: +2.72% (⬆️ mejora) — 2.13s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 1.3525
#    • MSE tras evolución: 1.3524
#    • Diferencia: +0.01% (⬆️ mejora) — 30.62s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 0.6307
#    • MSE tras evolución: 1.3287
#    • Diferencia: -110.67% (⬇️ empeora) — 2.83s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 1.1322
#    • MSE tras evolución: 1.1275
#    • Diferencia: +0.41% (⬆️ mejora) — 0.08s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 0.6273
#    • MSE tras evolución: 0.5224
#    • Diferencia: +16.72% (⬆️ mejora) — 3.79s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario DiversidadDirigida:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -1.52%
#    ▫️ Tiempo total evaluación modelos: 54.6s
#    ▫️ Tiempo optimizador: 53.7s
#    ▫️ Features generadas: 10
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: DiversidadDirigida | Dataset: Diabetes
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 50, 'mutation_prob': 0.55, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 40, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [DONE] Best fitness: -3444.92518 | Time: 192.5s
# ✅ Finalizado en 192.5 segundos | Fitness óptimo: -3444.9252
# ✨ Conjunto de entrenamiento ampliado a 16 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 2848.3107
#    • MSE tras evolución: 2814.3180
#    • Diferencia: +1.19% (⬆️ mejora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 3105.4721
#    • MSE tras evolución: 2801.6467
#    • Diferencia: +9.78% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 2846.0124
#    • MSE tras evolución: 2812.9637
#    • Diferencia: +1.16% (⬆️ mejora) — 0.01s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 2808.3122
#    • MSE tras evolución: 2775.4742
#    • Diferencia: +1.17% (⬆️ mejora) — 0.00s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 2826.1948
#    • MSE tras evolución: 2805.9242
#    • Diferencia: +0.72% (⬆️ mejora) — 0.00s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 5941.7027
#    • MSE tras evolución: 5257.8829
#    • Diferencia: +11.51% (⬆️ mejora) — 0.01s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 3010.1126
#    • MSE tras evolución: 2623.2400
#    • Diferencia: +12.85% (⬆️ mejora) — 0.34s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 2688.9871
#    • MSE tras evolución: 2588.2556
#    • Diferencia: +3.75% (⬆️ mejora) — 0.26s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 3184.4865
#    • MSE tras evolución: 2737.5157
#    • Diferencia: +14.04% (⬆️ mejora) — 0.26s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 2996.4917
#    • MSE tras evolución: 3004.1625
#    • Diferencia: -0.26% (⬇️ empeora) — 0.26s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 4511.8703
#    • MSE tras evolución: 5219.7280
#    • Diferencia: -15.69% (⬇️ empeora) — 0.02s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 6385.2818
#    • MSE tras evolución: 3735.5235
#    • Diferencia: +41.50% (⬆️ mejora) — 0.79s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 3060.1665
#    • MSE tras evolución: 2816.5351
#    • Diferencia: +7.96% (⬆️ mejora) — 2.27s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 2848.7123
#    • MSE tras evolución: 2864.7022
#    • Diferencia: -0.56% (⬇️ empeora) — 0.24s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario DiversidadDirigida:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: 6.37%
#    ▫️ Tiempo total evaluación modelos: 4.5s
#    ▫️ Tiempo optimizador: 192.5s
#    ▫️ Features generadas: 16
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: EquilibrioAdaptativo | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 25, 'mutation_prob': 0.35, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 49
# [DONE] Best fitness: -0.41228 | Time: 15.0s
# ✅ Finalizado en 15.0 segundos | Fitness óptimo: -0.4123
# ✨ Conjunto de entrenamiento ampliado a 12 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4440
#    • Diferencia: +17.95% (⬆️ mejora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4440
#    • Diferencia: +17.94% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 0.5394
#    • MSE tras evolución: 0.4430
#    • Diferencia: +17.88% (⬆️ mejora) — 1.01s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 0.5397
#    • MSE tras evolución: 0.4434
#    • Diferencia: +17.84% (⬆️ mejora) — 1.06s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 0.5408
#    • MSE tras evolución: 0.4439
#    • Diferencia: +17.92% (⬆️ mejora) — 0.01s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 0.5285
#    • MSE tras evolución: 0.4495
#    • Diferencia: +14.95% (⬆️ mejora) — 0.50s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 0.2542
#    • MSE tras evolución: 0.2352
#    • Diferencia: +7.49% (⬆️ mejora) — 4.62s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 0.2486
#    • MSE tras evolución: 0.2747
#    • Diferencia: -10.50% (⬇️ empeora) — 1.85s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 0.2895
#    • MSE tras evolución: 0.2865
#    • Diferencia: +1.04% (⬆️ mejora) — 9.02s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 0.8194
#    • MSE tras evolución: 0.7787
#    • Diferencia: +4.96% (⬆️ mejora) — 2.46s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 1.3525
#    • MSE tras evolución: 1.3472
#    • Diferencia: +0.40% (⬆️ mejora) — 31.50s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 0.6307
#    • MSE tras evolución: 0.5410
#    • Diferencia: +14.22% (⬆️ mejora) — 2.47s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 1.1322
#    • MSE tras evolución: 1.0773
#    • Diferencia: +4.85% (⬆️ mejora) — 0.09s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 0.6273
#    • MSE tras evolución: 0.5108
#    • Diferencia: +18.57% (⬆️ mejora) — 2.97s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario EquilibrioAdaptativo:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: 10.39%
#    ▫️ Tiempo total evaluación modelos: 57.6s
#    ▫️ Tiempo optimizador: 15.0s
#    ▫️ Features generadas: 12
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: EquilibrioAdaptativo | Dataset: Diabetes
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 25, 'mutation_prob': 0.35, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [DONE] Best fitness: -3431.96919 | Time: 194.1s
# ✅ Finalizado en 194.1 segundos | Fitness óptimo: -3431.9692
# ✨ Conjunto de entrenamiento ampliado a 16 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 2848.3107
#    • MSE tras evolución: 2777.5256
#    • Diferencia: +2.49% (⬆️ mejora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 3105.4721
#    • MSE tras evolución: 2982.8458
#    • Diferencia: +3.95% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 2846.0124
#    • MSE tras evolución: 2846.5352
#    • Diferencia: -0.02% (⬇️ empeora) — 0.00s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 2808.3122
#    • MSE tras evolución: 2829.0126
#    • Diferencia: -0.74% (⬇️ empeora) — 0.00s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 2826.1948
#    • MSE tras evolución: 2831.6610
#    • Diferencia: -0.19% (⬇️ empeora) — 0.02s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 5941.7027
#    • MSE tras evolución: 5507.2072
#    • Diferencia: +7.31% (⬆️ mejora) — 0.01s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 3010.1126
#    • MSE tras evolución: 2883.1672
#    • Diferencia: +4.22% (⬆️ mejora) — 0.32s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 2688.9871
#    • MSE tras evolución: 2873.8005
#    • Diferencia: -6.87% (⬇️ empeora) — 0.24s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 3184.4865
#    • MSE tras evolución: 3253.2491
#    • Diferencia: -2.16% (⬇️ empeora) — 0.24s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 2996.4917
#    • MSE tras evolución: 3008.5397
#    • Diferencia: -0.40% (⬇️ empeora) — 0.44s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 4511.8703
#    • MSE tras evolución: 4464.8199
#    • Diferencia: +1.04% (⬆️ mejora) — 0.02s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 6385.2818
#    • MSE tras evolución: 6877.3587
#    • Diferencia: -7.71% (⬇️ empeora) — 0.93s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 3060.1665
#    • MSE tras evolución: 3150.2825
#    • Diferencia: -2.94% (⬇️ empeora) — 0.01s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 2848.7123
#    • MSE tras evolución: 2852.7117
#    • Diferencia: -0.14% (⬇️ empeora) — 0.09s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario EquilibrioAdaptativo:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -0.15%
#    ▫️ Tiempo total evaluación modelos: 2.3s
#    ▫️ Tiempo optimizador: 194.1s
#    ▫️ Features generadas: 16
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: SeleccionRestringida | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 10, 'mutation_prob': 0.25, 'elitism': True, 'complexity_penalty': 0.0015, 'patience': 25, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 91
# [DONE] Best fitness: -0.40148 | Time: 9.0s
# ✅ Finalizado en 9.0 segundos | Fitness óptimo: -0.4015
# ✨ Conjunto de entrenamiento ampliado a 10 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4456
#    • Diferencia: +17.65% (⬆️ mejora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4456
#    • Diferencia: +17.64% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 0.5394
#    • MSE tras evolución: 0.4447
#    • Diferencia: +17.56% (⬆️ mejora) — 0.86s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 0.5397
#    • MSE tras evolución: 0.4451
#    • Diferencia: +17.53% (⬆️ mejora) — 0.89s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 0.5408
#    • MSE tras evolución: 0.4456
#    • Diferencia: +17.61% (⬆️ mejora) — 0.00s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 0.5285
#    • MSE tras evolución: 0.4428
#    • Diferencia: +16.22% (⬆️ mejora) — 0.35s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 0.2542
#    • MSE tras evolución: 0.2323
#    • Diferencia: +8.62% (⬆️ mejora) — 3.74s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 0.2486
#    • MSE tras evolución: 0.2603
#    • Diferencia: -4.71% (⬇️ empeora) — 1.55s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 0.2895
#    • MSE tras evolución: 0.2858
#    • Diferencia: +1.29% (⬆️ mejora) — 6.63s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 0.8194
#    • MSE tras evolución: 0.6588
#    • Diferencia: +19.60% (⬆️ mejora) — 1.45s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 1.3525
#    • MSE tras evolución: 1.3488
#    • Diferencia: +0.28% (⬆️ mejora) — 30.58s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 0.6307
#    • MSE tras evolución: 1.7632
#    • Diferencia: -179.54% (⬇️ empeora) — 2.74s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 1.1322
#    • MSE tras evolución: 1.0927
#    • Diferencia: +3.49% (⬆️ mejora) — 0.07s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 0.6273
#    • MSE tras evolución: 0.5150
#    • Diferencia: +17.90% (⬆️ mejora) — 2.29s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario SeleccionRestringida:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -2.06%
#    ▫️ Tiempo total evaluación modelos: 51.2s
#    ▫️ Tiempo optimizador: 9.0s
#    ▫️ Features generadas: 10
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: SeleccionRestringida | Dataset: Diabetes
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 10, 'mutation_prob': 0.25, 'elitism': True, 'complexity_penalty': 0.0015, 'patience': 25, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [DONE] Best fitness: -3449.89705 | Time: 187.0s
# ✅ Finalizado en 187.0 segundos | Fitness óptimo: -3449.8971
# ✨ Conjunto de entrenamiento ampliado a 14 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 2848.3107
#    • MSE tras evolución: 2907.4694
#    • Diferencia: -2.08% (⬇️ empeora) — 0.02s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 3105.4721
#    • MSE tras evolución: 2979.9840
#    • Diferencia: +4.04% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 2846.0124
#    • MSE tras evolución: 2824.8882
#    • Diferencia: +0.74% (⬆️ mejora) — 0.00s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 2808.3122
#    • MSE tras evolución: 2791.2884
#    • Diferencia: +0.61% (⬆️ mejora) — 0.00s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 2826.1948
#    • MSE tras evolución: 5600.6003
#    • Diferencia: -98.17% (⬇️ empeora) — 0.00s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 5941.7027
#    • MSE tras evolución: 5570.6126
#    • Diferencia: +6.25% (⬆️ mejora) — 0.01s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 3010.1126
#    • MSE tras evolución: 3005.0878
#    • Diferencia: +0.17% (⬆️ mejora) — 0.35s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 2688.9871
#    • MSE tras evolución: 2834.9958
#    • Diferencia: -5.43% (⬇️ empeora) — 0.24s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 3184.4865
#    • MSE tras evolución: 2983.0048
#    • Diferencia: +6.33% (⬆️ mejora) — 0.19s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 2996.4917
#    • MSE tras evolución: 2982.5008
#    • Diferencia: +0.47% (⬆️ mejora) — 0.26s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 4511.8703
#    • MSE tras evolución: 5581.0414
#    • Diferencia: -23.70% (⬇️ empeora) — 0.02s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 6385.2818
#    • MSE tras evolución: 4862.6454
#    • Diferencia: +23.85% (⬆️ mejora) — 0.69s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 3060.1665
#    • MSE tras evolución: 3765.6800
#    • Diferencia: -23.05% (⬇️ empeora) — 0.02s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 2848.7123
#    • MSE tras evolución: 2823.9634
#    • Diferencia: +0.87% (⬆️ mejora) — 0.23s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario SeleccionRestringida:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -7.79%
#    ▫️ Tiempo total evaluación modelos: 2.0s
#    ▫️ Tiempo optimizador: 187.0s
#    ▫️ Features generadas: 14
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: EvolucionConservadora | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 30, 'mutation_prob': 0.25, 'elitism': True, 'complexity_penalty': 0.006, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 35
# [DONE] Best fitness: -0.42973 | Time: 14.2s
# ✅ Finalizado en 14.2 segundos | Fitness óptimo: -0.4297
# ✨ Conjunto de entrenamiento ampliado a 11 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4534
#    • Diferencia: +16.21% (⬆️ mejora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4534
#    • Diferencia: +16.20% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 0.5394
#    • MSE tras evolución: 0.4522
#    • Diferencia: +16.17% (⬆️ mejora) — 4.51s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 0.5397
#    • MSE tras evolución: 0.4525
#    • Diferencia: +16.15% (⬆️ mejora) — 4.89s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 0.5408
#    • MSE tras evolución: 0.4533
#    • Diferencia: +16.19% (⬆️ mejora) — 0.01s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 0.5285
#    • MSE tras evolución: 0.5382
#    • Diferencia: -1.84% (⬇️ empeora) — 0.50s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 0.2542
#    • MSE tras evolución: 0.2587
#    • Diferencia: -1.74% (⬇️ empeora) — 4.79s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 0.2486
#    • MSE tras evolución: 0.2866
#    • Diferencia: -15.26% (⬇️ empeora) — 1.77s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 0.2895
#    • MSE tras evolución: 0.2883
#    • Diferencia: +0.43% (⬆️ mejora) — 8.46s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 0.8194
#    • MSE tras evolución: 0.7477
#    • Diferencia: +8.75% (⬆️ mejora) — 2.34s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 1.3525
#    • MSE tras evolución: 1.3055
#    • Diferencia: +3.48% (⬆️ mejora) — 30.00s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 0.6307
#    • MSE tras evolución: 1.9650
#    • Diferencia: -211.54% (⬇️ empeora) — 1.83s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 1.1322
#    • MSE tras evolución: 1.1940
#    • Diferencia: -5.45% (⬇️ empeora) — 0.08s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 0.6273
#    • MSE tras evolución: 0.5366
#    • Diferencia: +14.46% (⬆️ mejora) — 3.75s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario EvolucionConservadora:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -9.13%
#    ▫️ Tiempo total evaluación modelos: 62.9s
#    ▫️ Tiempo optimizador: 14.2s
#    ▫️ Features generadas: 11
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: EvolucionConservadora | Dataset: Diabetes
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 30, 'mutation_prob': 0.25, 'elitism': True, 'complexity_penalty': 0.006, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [DONE] Best fitness: -3423.65748 | Time: 215.0s
# ✅ Finalizado en 215.0 segundos | Fitness óptimo: -3423.6575
# ✨ Conjunto de entrenamiento ampliado a 16 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 2848.3107
#    • MSE tras evolución: 2756.9198
#    • Diferencia: +3.21% (⬆️ mejora) — 0.01s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 3105.4721
#    • MSE tras evolución: 2835.3050
#    • Diferencia: +8.70% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 2846.0124
#    • MSE tras evolución: 2759.9113
#    • Diferencia: +3.03% (⬆️ mejora) — 0.01s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 2808.3122
#    • MSE tras evolución: 2739.6152
#    • Diferencia: +2.45% (⬆️ mejora) — 0.01s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 2826.1948
#    • MSE tras evolución: 2757.7872
#    • Diferencia: +2.42% (⬆️ mejora) — 0.01s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 5941.7027
#    • MSE tras evolución: 5309.0270
#    • Diferencia: +10.65% (⬆️ mejora) — 0.01s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 3010.1126
#    • MSE tras evolución: 2623.7748
#    • Diferencia: +12.83% (⬆️ mejora) — 0.40s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 2688.9871
#    • MSE tras evolución: 2628.9119
#    • Diferencia: +2.23% (⬆️ mejora) — 0.24s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 3184.4865
#    • MSE tras evolución: 2941.9860
#    • Diferencia: +7.62% (⬆️ mejora) — 0.33s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 2996.4917
#    • MSE tras evolución: 2930.1286
#    • Diferencia: +2.21% (⬆️ mejora) — 0.34s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 4511.8703
#    • MSE tras evolución: 4299.0756
#    • Diferencia: +4.72% (⬆️ mejora) — 0.03s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 6385.2818
#    • MSE tras evolución: 6662.5193
#    • Diferencia: -4.34% (⬇️ empeora) — 0.83s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 3060.1665
#    • MSE tras evolución: 3222.2703
#    • Diferencia: -5.30% (⬇️ empeora) — 0.01s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 2848.7123
#    • MSE tras evolución: 2800.0904
#    • Diferencia: +1.71% (⬆️ mejora) — 0.13s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario EvolucionConservadora:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: 3.72%
#    ▫️ Tiempo total evaluación modelos: 2.4s
#    ▫️ Tiempo optimizador: 215.0s
#    ▫️ Features generadas: 16
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: MicroEvolucion | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 12, 'mutation_prob': 0.3, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 60, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 74
# [DONE] Best fitness: -0.41278 | Time: 11.6s
# ✅ Finalizado en 11.6 segundos | Fitness óptimo: -0.4128
# ✨ Conjunto de entrenamiento ampliado a 14 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4456
#    • Diferencia: +17.65% (⬆️ mejora) — 0.01s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4456
#    • Diferencia: +17.64% (⬆️ mejora) — 0.01s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 0.5394
#    • MSE tras evolución: 0.4447
#    • Diferencia: +17.56% (⬆️ mejora) — 6.47s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 0.5397
#    • MSE tras evolución: 0.4451
#    • Diferencia: +17.53% (⬆️ mejora) — 12.50s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 0.5408
#    • MSE tras evolución: 0.4456
#    • Diferencia: +17.61% (⬆️ mejora) — 0.01s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 0.5285
#    • MSE tras evolución: 0.4574
#    • Diferencia: +13.46% (⬆️ mejora) — 0.62s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 0.2542
#    • MSE tras evolución: 0.2354
#    • Diferencia: +7.39% (⬆️ mejora) — 5.26s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 0.2486
#    • MSE tras evolución: 0.2742
#    • Diferencia: -10.30% (⬇️ empeora) — 1.99s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 0.2895
#    • MSE tras evolución: 0.2856
#    • Diferencia: +1.36% (⬆️ mejora) — 11.20s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 0.8194
#    • MSE tras evolución: 0.8015
#    • Diferencia: +2.19% (⬆️ mejora) — 3.14s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 1.3525
#    • MSE tras evolución: 1.3610
#    • Diferencia: -0.63% (⬇️ empeora) — 33.19s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 0.6307
#    • MSE tras evolución: 1.2314
#    • Diferencia: -95.23% (⬇️ empeora) — 2.74s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 1.1322
#    • MSE tras evolución: 1.1763
#    • Diferencia: -3.89% (⬇️ empeora) — 0.10s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 0.6273
#    • MSE tras evolución: 0.5150
#    • Diferencia: +17.91% (⬆️ mejora) — 3.11s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario MicroEvolucion:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: 1.45%
#    ▫️ Tiempo total evaluación modelos: 80.4s
#    ▫️ Tiempo optimizador: 11.6s
#    ▫️ Features generadas: 14
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: MicroEvolucion | Dataset: Diabetes
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 12, 'mutation_prob': 0.3, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 60, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [DONE] Best fitness: -3407.37204 | Time: 187.2s
# ✅ Finalizado en 187.2 segundos | Fitness óptimo: -3407.3720
# ✨ Conjunto de entrenamiento ampliado a 14 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 2848.3107
#    • MSE tras evolución: 2754.8524
#    • Diferencia: +3.28% (⬆️ mejora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 3105.4721
#    • MSE tras evolución: 2989.3134
#    • Diferencia: +3.74% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 2846.0124
#    • MSE tras evolución: 2753.0886
#    • Diferencia: +3.27% (⬆️ mejora) — 0.01s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 2808.3122
#    • MSE tras evolución: 2752.7661
#    • Diferencia: +1.98% (⬆️ mejora) — 0.00s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 2826.1948
#    • MSE tras evolución: 5519.9652
#    • Diferencia: -95.31% (⬇️ empeora) — 0.00s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 5941.7027
#    • MSE tras evolución: 5654.3153
#    • Diferencia: +4.84% (⬆️ mejora) — 0.01s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 3010.1126
#    • MSE tras evolución: 2867.8336
#    • Diferencia: +4.73% (⬆️ mejora) — 0.35s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 2688.9871
#    • MSE tras evolución: 2730.5622
#    • Diferencia: -1.55% (⬇️ empeora) — 0.24s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 3184.4865
#    • MSE tras evolución: 3018.4456
#    • Diferencia: +5.21% (⬆️ mejora) — 0.24s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 2996.4917
#    • MSE tras evolución: 3005.2561
#    • Diferencia: -0.29% (⬇️ empeora) — 0.33s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 4511.8703
#    • MSE tras evolución: 5510.8135
#    • Diferencia: -22.14% (⬇️ empeora) — 0.02s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 6385.2818
#    • MSE tras evolución: 5041.5529
#    • Diferencia: +21.04% (⬆️ mejora) — 0.84s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 3060.1665
#    • MSE tras evolución: 4904.1153
#    • Diferencia: -60.26% (⬇️ empeora) — 0.00s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 2848.7123
#    • MSE tras evolución: 2759.0887
#    • Diferencia: +3.15% (⬆️ mejora) — 0.29s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario MicroEvolucion:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -9.17%
#    ▫️ Tiempo total evaluación modelos: 2.3s
#    ▫️ Tiempo optimizador: 187.2s
#    ▫️ Features generadas: 14
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: SinElitismo | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 25, 'mutation_prob': 0.35, 'elitism': False, 'complexity_penalty': 0.001, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 30
# [DONE] Best fitness: -0.41738 | Time: 10.2s
# ✅ Finalizado en 10.2 segundos | Fitness óptimo: -0.4174
# ✨ Conjunto de entrenamiento ampliado a 13 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4383
#    • Diferencia: +19.00% (⬆️ mejora) — 0.01s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4383
#    • Diferencia: +18.99% (⬆️ mejora) — 0.01s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 0.5394
#    • MSE tras evolución: 0.4377
#    • Diferencia: +18.85% (⬆️ mejora) — 12.44s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 0.5397
#    • MSE tras evolución: 0.4380
#    • Diferencia: +18.84% (⬆️ mejora) — 12.07s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 0.5408
#    • MSE tras evolución: 0.4383
#    • Diferencia: +18.96% (⬆️ mejora) — 0.00s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 0.5285
#    • MSE tras evolución: 0.4652
#    • Diferencia: +11.98% (⬆️ mejora) — 0.42s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 0.2542
#    • MSE tras evolución: 0.2314
#    • Diferencia: +8.99% (⬆️ mejora) — 4.58s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 0.2486
#    • MSE tras evolución: 0.2539
#    • Diferencia: -2.11% (⬇️ empeora) — 1.78s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 0.2895
#    • MSE tras evolución: 0.2798
#    • Diferencia: +3.34% (⬆️ mejora) — 9.26s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 0.8194
#    • MSE tras evolución: 0.7694
#    • Diferencia: +6.10% (⬆️ mejora) — 2.67s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 1.3525
#    • MSE tras evolución: 1.3642
#    • Diferencia: -0.86% (⬇️ empeora) — 32.61s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 0.6307
#    • MSE tras evolución: 0.6603
#    • Diferencia: -4.70% (⬇️ empeora) — 1.70s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 1.1322
#    • MSE tras evolución: 1.1780
#    • Diferencia: -4.04% (⬇️ empeora) — 0.11s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 0.6273
#    • MSE tras evolución: 0.5101
#    • Diferencia: +18.68% (⬆️ mejora) — 3.04s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario SinElitismo:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: 9.43%
#    ▫️ Tiempo total evaluación modelos: 80.7s
#    ▫️ Tiempo optimizador: 10.2s
#    ▫️ Features generadas: 13
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: SinElitismo | Dataset: Diabetes
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 25, 'mutation_prob': 0.35, 'elitism': False, 'complexity_penalty': 0.001, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [DONE] Best fitness: -3456.28938 | Time: 204.0s
# ✅ Finalizado en 204.0 segundos | Fitness óptimo: -3456.2894
# ✨ Conjunto de entrenamiento ampliado a 15 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 2848.3107
#    • MSE tras evolución: 2906.9471
#    • Diferencia: -2.06% (⬇️ empeora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 3105.4721
#    • MSE tras evolución: 3155.0802
#    • Diferencia: -1.60% (⬇️ empeora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 2846.0124
#    • MSE tras evolución: 2904.9920
#    • Diferencia: -2.07% (⬇️ empeora) — 0.01s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 2808.3122
#    • MSE tras evolución: 2892.3857
#    • Diferencia: -2.99% (⬇️ empeora) — 0.00s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 2826.1948
#    • MSE tras evolución: 5607.1105
#    • Diferencia: -98.40% (⬇️ empeora) — 0.00s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 5941.7027
#    • MSE tras evolución: 7084.2973
#    • Diferencia: -19.23% (⬇️ empeora) — 0.00s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 3010.1126
#    • MSE tras evolución: 2968.3646
#    • Diferencia: +1.39% (⬆️ mejora) — 0.34s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 2688.9871
#    • MSE tras evolución: 2697.7099
#    • Diferencia: -0.32% (⬇️ empeora) — 0.24s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 3184.4865
#    • MSE tras evolución: 3184.3884
#    • Diferencia: +0.00% (⬆️ mejora) — 0.22s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 2996.4917
#    • MSE tras evolución: 2919.8154
#    • Diferencia: +2.56% (⬆️ mejora) — 0.29s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 4511.8703
#    • MSE tras evolución: 5545.3591
#    • Diferencia: -22.91% (⬇️ empeora) — 0.01s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 6385.2818
#    • MSE tras evolución: 5395.2860
#    • Diferencia: +15.50% (⬆️ mejora) — 0.72s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 3060.1665
#    • MSE tras evolución: 5222.8357
#    • Diferencia: -70.67% (⬇️ empeora) — 0.00s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 2848.7123
#    • MSE tras evolución: 2910.5740
#    • Diferencia: -2.17% (⬇️ empeora) — 0.31s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario SinElitismo:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -14.50%
#    ▫️ Tiempo total evaluación modelos: 2.2s
#    ▫️ Tiempo optimizador: 204.0s
#    ▫️ Features generadas: 15
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: MutacionBaja | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 25, 'mutation_prob': 0.2, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 47
# [DONE] Best fitness: -0.41484 | Time: 12.7s
# ✅ Finalizado en 12.7 segundos | Fitness óptimo: -0.4148
# ✨ Conjunto de entrenamiento ampliado a 11 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4687
#    • Diferencia: +13.39% (⬆️ mejora) — 0.01s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4687
#    • Diferencia: +13.38% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 0.5394
#    • MSE tras evolución: 0.4677
#    • Diferencia: +13.30% (⬆️ mejora) — 2.36s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 0.5397
#    • MSE tras evolución: 0.4681
#    • Diferencia: +13.27% (⬆️ mejora) — 3.39s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 0.5408
#    • MSE tras evolución: 0.4687
#    • Diferencia: +13.35% (⬆️ mejora) — 0.01s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 0.5285
#    • MSE tras evolución: 0.5314
#    • Diferencia: -0.54% (⬇️ empeora) — 0.41s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 0.2542
#    • MSE tras evolución: 0.2561
#    • Diferencia: -0.73% (⬇️ empeora) — 4.05s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 0.2486
#    • MSE tras evolución: 0.2677
#    • Diferencia: -7.69% (⬇️ empeora) — 1.66s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 0.2895
#    • MSE tras evolución: 0.2905
#    • Diferencia: -0.35% (⬇️ empeora) — 9.03s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 0.8194
#    • MSE tras evolución: 0.7209
#    • Diferencia: +12.01% (⬆️ mejora) — 2.31s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 1.3525
#    • MSE tras evolución: 1.3528
#    • Diferencia: -0.02% (⬇️ empeora) — 33.92s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 0.6307
#    • MSE tras evolución: 0.5793
#    • Diferencia: +8.15% (⬆️ mejora) — 3.88s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 1.1322
#    • MSE tras evolución: 1.1468
#    • Diferencia: -1.29% (⬇️ empeora) — 0.09s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 0.6273
#    • MSE tras evolución: 0.5345
#    • Diferencia: +14.79% (⬆️ mejora) — 2.35s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario MutacionBaja:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: 6.50%
#    ▫️ Tiempo total evaluación modelos: 63.5s
#    ▫️ Tiempo optimizador: 12.7s
#    ▫️ Features generadas: 11
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: MutacionBaja | Dataset: Diabetes
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 25, 'mutation_prob': 0.2, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [DONE] Best fitness: -3423.85867 | Time: 187.0s
# ✅ Finalizado en 187.0 segundos | Fitness óptimo: -3423.8587
# ✨ Conjunto de entrenamiento ampliado a 14 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 2848.3107
#    • MSE tras evolución: 2905.3476
#    • Diferencia: -2.00% (⬇️ empeora) — 0.00s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 3105.4721
#    • MSE tras evolución: 3070.1855
#    • Diferencia: +1.14% (⬆️ mejora) — 0.00s
#
# [03/14] 🧠 Evaluando Lasso...
#    • MSE base: 2846.0124
#    • MSE tras evolución: 2903.1117
#    • Diferencia: -2.01% (⬇️ empeora) — 0.01s
#
# [04/14] 🧠 Evaluando ElasticNet...
#    • MSE base: 2808.3122
#    • MSE tras evolución: 2903.8130
#    • Diferencia: -3.40% (⬇️ empeora) — 0.00s
#
# [05/14] 🧠 Evaluando BayesianRidge...
#    • MSE base: 2826.1948
#    • MSE tras evolución: 2896.5596
#    • Diferencia: -2.49% (⬇️ empeora) — 0.01s
#
# [06/14] 🧠 Evaluando DecisionTree...
#    • MSE base: 5941.7027
#    • MSE tras evolución: 5907.4685
#    • Diferencia: +0.58% (⬆️ mejora) — 0.01s
#
# [07/14] 🧠 Evaluando RandomForest...
#    • MSE base: 3010.1126
#    • MSE tras evolución: 2969.9517
#    • Diferencia: +1.33% (⬆️ mejora) — 0.44s
#
# [08/14] 🧠 Evaluando ExtraTrees...
#    • MSE base: 2688.9871
#    • MSE tras evolución: 2830.1545
#    • Diferencia: -5.25% (⬇️ empeora) — 0.25s
#
# [09/14] 🧠 Evaluando GradientBoosting...
#    • MSE base: 3184.4865
#    • MSE tras evolución: 3029.9212
#    • Diferencia: +4.85% (⬆️ mejora) — 0.27s
#
# [10/14] 🧠 Evaluando AdaBoost...
#    • MSE base: 2996.4917
#    • MSE tras evolución: 2991.0364
#    • Diferencia: +0.18% (⬆️ mejora) — 0.41s
#
# [11/14] 🧠 Evaluando SVR...
#    • MSE base: 4511.8703
#    • MSE tras evolución: 4487.3396
#    • Diferencia: +0.54% (⬆️ mejora) — 0.02s
#
# [12/14] 🧠 Evaluando MLP...
#    • MSE base: 6385.2818
#    • MSE tras evolución: 6283.5197
#    • Diferencia: +1.59% (⬆️ mejora) — 0.86s
#
# [13/14] 🧠 Evaluando KNeighbors...
#    • MSE base: 3060.1665
#    • MSE tras evolución: 3668.9517
#    • Diferencia: -19.89% (⬇️ empeora) — 0.01s
#
# [14/14] 🧠 Evaluando Huber...
#    • MSE base: 2848.7123
#    • MSE tras evolución: 2910.8169
#    • Diferencia: -2.18% (⬇️ empeora) — 0.14s
#
# ----------------------------------------------------------------------
# 🧾 Resumen del escenario MutacionBaja:
#    ▫️ Modelos evaluados: 14
#    ▫️ Mejora media: -1.93%
#    ▫️ Tiempo total evaluación modelos: 2.4s
#    ▫️ Tiempo optimizador: 187.0s
#    ▫️ Features generadas: 14
# ----------------------------------------------------------------------
#
# ==========================================================================================
# 🧩 Escenario: MutacionAlta | Dataset: California
# ==========================================================================================
# 🔧 Parámetros evolutivos → {'pop_size': 25, 'mutation_prob': 0.6, 'elitism': True, 'complexity_penalty': 0.001, 'patience': 30, 'generations': 9999}
#
# 🚀 Iniciando optimización evolutiva...
# [STOP] Early stopping at gen 37
# [DONE] Best fitness: -0.41048 | Time: 12.7s
# ✅ Finalizado en 12.7 segundos | Fitness óptimo: -0.4105
# ✨ Conjunto de entrenamiento ampliado a 14 variables tras la evolución.
# ----------------------------------------------------------------------
#
# [01/14] 🧠 Evaluando LinearRegression...
#    • MSE base: 0.5411
#    • MSE tras evolución: 0.4425
#    • Diferencia: +18.22% (⬆️ mejora) — 0.01s
#
# [02/14] 🧠 Evaluando Ridge...
#    • MSE base: 0.5410
#    • MSE tras evolución: 0.4432
#    • Diferencia: +18.09% (⬆️ mejora) — 0.01s
#
# [03/14] 🧠 Evaluando Lasso...

# %%
# Out:
# ✅ Airfoil Self-Noise cargado correctamente.
# ⚠️ No se pudo cargar Concrete Strength: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.
# ⚠️ No se pudo cargar Energy Efficiency: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
# ⚠️ No se pudo cargar Wine Quality (Red): name 'DATASETS_EXTRA' is not defined
#
# ====================================================================================================
# 🏁 Dataset: AirfoilNoise
# ====================================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 74
#      71 y = df.iloc[:, -1].values
#      72 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# ---> 74 evo = EvolutionaryOptimizer(maxtime=MAXTIME, **evo_params)
#      76 evo.fit(X_train, y_train)
#      77 X_train_opt = evo.transform(X_train)
#
# NameError: name 'EvolutionaryOptimizer' is not defined
